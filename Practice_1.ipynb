# %% [markdown]
# **QUESTION 1**
# Write a Python program that takes the user’s age as input. Since the input function returns a
# string, convert the entered value into an integer using typecasting. After conversion, display the
# user’s age for the next five years.
# Requirements:
#  Use the input() function to take user input.
#  Use appropriate typecasting to convert the input into an integer.
#  Use a loop to display age progression for the next five years.
#  Display the output in a readable format.

# %%
age_string = input("Enter your age in numbers: ")
age_numeric = int(age_string)

for i in range(5):
  print(f"Year 202{i+ 1} = Age: {age_numeric + i + 1}")
# Out:
# Enter your age in numbers: 20
# Year 2021 = Age: 21
# Year 2022 = Age: 22
# Year 2023 = Age: 23
# Year 2024 = Age: 24
# Year 2025 = Age: 25

# %% [markdown]
# **QUESTION 2**
#
# Write a Python program that takes two numbers as input from the user and performs the
# following arithmetic operations:
#  Addition
#  Subtraction
#  Multiplication
#  Division
#  Modulus
# Display the result of each operation clearly.

# %%
num1 = input("Enter first number: ")
num2 = input("Enter second number: ")

num1 = int(num1)
num2 = int(num2)

print(f"Addition of 2 number is {num1} + {num2} = {num1 + num2}")
print(f"Subtraction of 2 number is {num1} - {num2} = {num1 - num2}")
print(f"Multiplication of 2 number is {num1} x {num2} = {num1 * num2}")
print(f"Division of 2 number is {num1} / {num2} = {num1 / num2}")
print(f"Modulus of 2 number is {num1} % {num2} = {num1 % num2}")
# Out:
# Enter first number: 5
# Enter second number: 10
# Addition of 2 number is 5 + 10 = 15
# Subtraction of 2 number is 5 - 10 = -5
# Multiplication of 2 number is 5 x 10 = 50
# Division of 2 number is 5 / 10 = 0.5
# Modulus of 2 number is 5 % 10 = 5

# %% [markdown]
# **QUESTION 3**
# Write a Python program that takes the marks of a student as input and prints the corresponding
# grade according to the following criteria:
#  Marks ≥ 85 → Grade A
#  Marks ≥ 70 and < 85 → Grade B
#
# AL2002: Artificial Intelligence Lab
#
#  Marks ≥ 50 and < 70 → Grade C
#  Marks < 50 → Fail
# Requirements:
#  Use if, elif, and else statements.
#  Ensure correct comparison operators are used.
#  Display the final grade clearly.

# %%
marks = input("Enter marks of the student: ")

marks = float(marks)

if marks >= 85:
  print("Grade A")
elif marks >= 70 and  marks < 85:
  print("Grade B")
elif marks >= 50 and marks < 70:
  print("Grade C")
else:
  print("FAIL")
# Out:
# Enter marks of the student: 78.6
# Grade B

# %% [markdown]
# **QUESTION 4**
#
# Write a Python program that repeatedly asks the user to enter a password until the correct
# password is entered.
# Requirements:
#  Use a while loop.
#  If the entered password is incorrect, ask again.
#  When the correct password is entered, print a success message and terminate the
# program.
#  Use break to exit the loop.

# %%
password = "AzibNaeem"
inp = ""
count = 0
while 1:
  if count == 0:
    inp = input("Enter your password:")
  if count:
    inp = input("Enter your password again:")
  if inp == password:
    print("Success")
    break
  else:
    count = count + 1
    print("Wrong password!")
# Out:
# Enter your password:AzibNaeem
# Success

# %% [markdown]
# **QUESTION 5**
# Write a Python program that takes a number as input from the user and prints its multiplication
# table from 1 to 10.
# Requirements:
#  Use a for loop with the range() function.
#  Display the output in the format:
# number × i = result

# %%
number = input("Enter the number you want to make the table of: ")
number = int(number)

for i in range (1, 11):
  print(f"{number} x {i} = {number * i}")
# Out:
# Enter the number you want to make the table of: 10
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 3 = 30
# 10 x 4 = 40
# 10 x 5 = 50
# 10 x 6 = 60
# 10 x 7 = 70
# 10 x 8 = 80
# 10 x 9 = 90
# 10 x 10 = 100

# %% [markdown]
# **QUESTION 6**
#
# Write a Python program that defines and uses the following user-defined functions:
# 1. A function that checks whether a given number is even or odd.
# 2. A function that calculates the factorial of a given number.
#
# AL2002: Artificial Intelligence Lab
# The program should take input from the user and display the result using function calls.
# Requirements:
#  Use the def keyword to define functions.
#  Use appropriate return statements.
#  Call functions from the main program.

# %%
def evenOdd(number):
  if number % 2 == 0:
    print("Number is even")
  if number % 2 != 0:
    print("Number is odd")

def fact(number):
  fact = 1
  for i in range(number):
    fact = fact * (i + 1)
  return fact

number1 = input("Enter any number: ")
number1 = int(number1)

evenOdd(number1)
print(f"Factorial of the number is: {fact(number1)}")
# Out:
# Enter any number: 6
# Number is even
# Factorial of the number is: 720

# %% [markdown]
# **QUESTION 7**
#
# Write a Python program that acts as a simple Student Information System. The program should
# perform the following tasks:
#  Take the student’s name, age, and marks as input.
#  Convert age and marks into appropriate numeric data types.
#  Determine the student’s grade using conditional statements.
#  Display the student’s complete information in a formatted manner.
# Requirements:
#  Use input() and typecasting.
#  Use if–elif–else for grade calculation.
#  Use print formatting for clear output.

# %%
name = input("Enter the name of the student: ")
age = input("Enter the age of the student: ")
age = int(age)
marks = input("Enter the marks of the student: ")
marks = int(marks)

if marks >= 85:
  result = "Grade A"
elif marks >= 70 and  marks < 85:
  result = "Grade B"
elif marks >= 50 and marks < 70:
  result = "Grade C"
else:
  result = "FAIL"


print("------------------------STUDENT INFORMATION SYSTEM------------------------------------\n")
print(f"The name of the student is: {name}")
print(f"The age of the student is: {age}")
print(f"The marks of the student is: {marks}")
print(f"The grade of the student is: {result}")
print("\n--------------------------------------------------------------------------------------")
# Out:
# Enter the name of the student: Azib Naeem
# Enter the age of the student: 20
# Enter the marks of the student: 98
# ------------------------STUDENT INFORMATION SYSTEM------------------------------------
#
# The name of the student is: Azib Naeem
# The age of the student is: 20
# The marks of the student is: 98
# The grade of the student is: Grade A
#
# --------------------------------------------------------------------------------------

# %% [markdown]
# **QUESTION 8**
#
# Write a function that reverses a string. The input string is given as an array of characters. You
# can use Python list to create the array of characters. Do not allocate extra space for another array,
# you must do this reversal by modifying the input array in-place with O(1) extra memory.
# Example 1:
# Input: ["h","e","l","l","o"]
# Output: ["o","l","l","e","h"]
# Example 2:
# Input: ["H","a","n","n","a","h"]
# Output: ["h","a","n","n","a","H"]

# %%
def reversal(str):
  left = 0
  right = len(str) - 1
  while left < right:
    str[left] , str[right] = str[right], str[left]
    left = left + 1
    right = right -1
  return str

str = ["h", "e", "l", "l", "o"]
reversal = reversal(str)
print(reversal)
# Out:
# ['o', 'l', 'l', 'e', 'h']

# %% [markdown]
# **QUESTION 9**
#
# Given a string s, determine if it is a palindrome, considering only alphanumeric characters and
# ignoring cases. Refer to this link to learn about Python string functions which might come handy
#
# AL2002: Artificial Intelligence Lab
#
# in this task.
# Example 1:
# Input: s = "A man, a plan, a canal: Panama"
# Output: true
# Explanation: "amanaplanacanalpanama" is a palindrome.
# Example 2:
# Input: s = "race a car"
# Output: false
# Explanation: "raceacar" is not a palindrome.

# %%
str_input = "A man, a plan, a canal: Panama"

alphanumeric_str = ""
for char in str_input:
  if char.isalnum():
    alphanumeric_str += char.lower()


if alphanumeric_str == alphanumeric_str[::-1]:
  print("Is a palindrome!")
else:
  print("Not a Palindrome!")
# Out:
# Is a palindrome!

# %% [markdown]
# **QUESTION 10**
#
# Given a non-negative integer x, compute and return the square root of x.
# Since the return type is an integer, the decimal digits are truncated, and only the integer part of
# the result is returned.
# Example 1:
# Input: x = 4
# Output: 2
# Example 2:
# Input: x = 8
# Output: 2
# Explanation: The square root of 8 is 2.82842..., and since the decimal part is truncated, 2 is
# returned.

# %%
def binary(number):
  left = 0
  right = number
  mid = left + (right - left) // 2
  while left <= right:
    if mid * mid == number:
      return mid
      break
    if mid * mid <= number:
      left = mid + 1
      result = mid
    else:
      right = mid - 1
    mid = left + (right - left) // 2
  return result

number = 8
print(f"the square root of the number is: {binary(number)}")

number = 9
print(f"the square root of the number is: {binary(number)}")
# Out:
# the square root of the number is: 2
# the square root of the number is: 3
